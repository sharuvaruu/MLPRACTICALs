# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
dataset = pd.read_csv(r"C:\Users\Hp\Desktop\cardekho_data.csv")

# %%
df=pd.DataFrame(dataset)

# %%
df
# Out:
#          Car_Name    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0            ritz  2014.0           3.35            NaN     27000.0    Petrol
# 1             sx4  2013.0           4.75           9.54     43000.0    Diesel
# 2            ciaz  2017.0           7.25           9.85      6900.0    Petrol
# 3         wagon r     NaN           2.85           4.15      5200.0    Petrol
# 4           swift  2014.0           4.60           6.87     42450.0    Diesel
# 5   vitara brezza  2018.0            NaN           9.83      2071.0    Diesel
# 6            ciaz  2015.0           6.75           8.12     18796.0    Petrol
# 7         s cross  2015.0           6.50           8.61     33429.0       NaN
# 8            ciaz  2016.0           8.75           8.89     20273.0    Diesel
# 9             NaN  2015.0           7.45            NaN     42367.0    Diesel
# 10       alto 800  2017.0           2.85           3.60      2135.0    Petrol
# ...

# %%
A = df.iloc[:, :-1].values
B = df.iloc[:, -1].values
print(A)
print(B)
# Out:
# [['ritz' 2014.0 3.35 nan 27000.0 'Petrol' 'Dealer' 'Manual']
#  ['sx4' 2013.0 4.75 9.54 43000.0 'Diesel' 'Dealer' 'Manual']
#  ['ciaz' 2017.0 7.25 9.85 6900.0 'Petrol' 'Dealer' 'Manual']
#  ['wagon r' nan 2.85 4.15 5200.0 'Petrol' nan 'Manual']
#  ['swift' 2014.0 4.6 6.87 42450.0 'Diesel' 'Dealer' 'Manual']
#  ['vitara brezza' 2018.0 nan 9.83 2071.0 'Diesel' 'Dealer' 'Manual']
#  ['ciaz' 2015.0 6.75 8.12 18796.0 'Petrol' 'Dealer' 'Manual']
#  ['s cross' 2015.0 6.5 8.61 33429.0 nan 'Dealer' 'Manual']
#  ['ciaz' 2016.0 8.75 8.89 20273.0 'Diesel' 'Dealer' 'Manual']
#  [nan 2015.0 7.45 nan 42367.0 'Diesel' 'Dealer' nan]
#  ['alto 800' 2017.0 2.85 3.6 2135.0 'Petrol' 'Dealer' 'Manual']
#  ['ciaz' nan 6.85 10.38 51000.0 'Diesel' 'Dealer' 'Manual']
#  ['ciaz' 2015.0 7.5 9.94 15000.0 nan 'Dealer' 'Automatic']
#  ['ertiga' 2015.0 6.1 7.71 26000.0 'Petrol' 'Dealer' 'Manual']
#  ['dzire' 2009.0 2.25 7.21 77427.0 'Petrol' 'Dealer' 'Manual']
#  ['ertiga' 2016.0 7.75 10.79 nan 'Diesel' nan nan]
# ...

# %%
df.isnull().sum()
# Out:
# Car_Name         2
# Year             4
# Selling_Price    1
# Present_Price    3
# Kms_Driven       2
# Fuel_Type        3
# Seller_Type      3
# Transmission     3
# Owner            1
# dtype: int64

# %%
print("Before:",df.shape)
df.dropna(inplace=True)
print("After:",df.shape)
# Out:
# Before: (29, 9)
# After: (15, 9)

# %%
df2 = df.copy()
df2
# Out:
#     Car_Name    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 1        sx4  2013.0           4.75           9.54     43000.0    Diesel
# 2       ciaz  2017.0           7.25           9.85      6900.0    Petrol
# 4      swift  2014.0           4.60           6.87     42450.0    Diesel
# 6       ciaz  2015.0           6.75           8.12     18796.0    Petrol
# 8       ciaz  2016.0           8.75           8.89     20273.0    Diesel
# 10  alto 800  2017.0           2.85           3.60      2135.0    Petrol
# 13    ertiga  2015.0           6.10           7.71     26000.0    Petrol
# 14     dzire  2009.0           2.25           7.21     77427.0    Petrol
# 16    ertiga  2015.0           7.25          10.79     41678.0    Diesel
# 18   wagon r  2015.0           3.25           5.09     35500.0       CNG
# 20  alto k10  2016.0           2.85           3.95     25000.0    Petrol
# 22       sx4  2011.0           4.40           8.01     50000.0    Petrol
# ...

# %%
df2.mean
# Out:
# <bound method DataFrame.mean of     Car_Name    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 1        sx4  2013.0           4.75           9.54     43000.0    Diesel
# 2       ciaz  2017.0           7.25           9.85      6900.0    Petrol
# 4      swift  2014.0           4.60           6.87     42450.0    Diesel
# 6       ciaz  2015.0           6.75           8.12     18796.0    Petrol
# 8       ciaz  2016.0           8.75           8.89     20273.0    Diesel
# 10  alto 800  2017.0           2.85           3.60      2135.0    Petrol
# 13    ertiga  2015.0           6.10           7.71     26000.0    Petrol
# 14     dzire  2009.0           2.25           7.21     77427.0    Petrol
# 16    ertiga  2015.0           7.25          10.79     41678.0    Diesel
# 18   wagon r  2015.0           3.25           5.09     35500.0       CNG
# 20  alto k10  2016.0           2.85           3.95     25000.0    Petrol
# ...

# %%
numerical_cols = ['Year', 'Selling_Price', 'Present_Price', 'Kms_Driven']
df[numerical_cols] = df[numerical_cols].fillna(df[numerical_cols].mean())

categorical_cols = ['Fuel_Type', 'Seller_Type', 'Transmission', 'Owner']
df[categorical_cols] = df[categorical_cols].fillna(df[categorical_cols].mode().iloc[0])
print(df)
# Out:
#          Car_Name     Year  Selling_Price  Present_Price    Kms_Driven  \
# 0            ritz  2014.00       3.350000       7.269231  27000.000000
# 1             sx4  2013.00       4.750000       9.540000  43000.000000
# 2            ciaz  2017.00       7.250000       9.850000   6900.000000
# 3         wagon r  2014.28       2.850000       4.150000   5200.000000
# 4           swift  2014.00       4.600000       6.870000  42450.000000
# 5   vitara brezza  2018.00       4.967857       9.830000   2071.000000
# 6            ciaz  2015.00       6.750000       8.120000  18796.000000
# 7         s cross  2015.00       6.500000       8.610000  33429.000000
# 8            ciaz  2016.00       8.750000       8.890000  20273.000000
# 9             NaN  2015.00       7.450000       7.269231  42367.000000
# 10       alto 800  2017.00       2.850000       3.600000   2135.000000
# 11           ciaz  2014.28       6.850000      10.380000  51000.000000
# ...

# %%
df.replace({'Fuel_Type': {'Petrol': 1, 'Diesel': 2, 'CNG': 3}}, inplace=True)
print(df)
# Out:
#          Car_Name     Year  Selling_Price  Present_Price    Kms_Driven  \
# 0            ritz  2014.00       3.350000       7.269231  27000.000000
# 1             sx4  2013.00       4.750000       9.540000  43000.000000
# 2            ciaz  2017.00       7.250000       9.850000   6900.000000
# 3         wagon r  2014.28       2.850000       4.150000   5200.000000
# 4           swift  2014.00       4.600000       6.870000  42450.000000
# 5   vitara brezza  2018.00       4.967857       9.830000   2071.000000
# 6            ciaz  2015.00       6.750000       8.120000  18796.000000
# 7         s cross  2015.00       6.500000       8.610000  33429.000000
# 8            ciaz  2016.00       8.750000       8.890000  20273.000000
# 9             NaN  2015.00       7.450000       7.269231  42367.000000
# 10       alto 800  2017.00       2.850000       3.600000   2135.000000
# 11           ciaz  2014.28       6.850000      10.380000  51000.000000
# ...

# %%
# Create a boolean series indicating True for NaN values
nan_bool_series = df.isna()
print(df)
# Out:
#          Car_Name     Year  Selling_Price  Present_Price    Kms_Driven  \
# 0            ritz  2014.00       3.350000       7.269231  27000.000000
# 1             sx4  2013.00       4.750000       9.540000  43000.000000
# 2            ciaz  2017.00       7.250000       9.850000   6900.000000
# 3         wagon r  2014.28       2.850000       4.150000   5200.000000
# 4           swift  2014.00       4.600000       6.870000  42450.000000
# 5   vitara brezza  2018.00       4.967857       9.830000   2071.000000
# 6            ciaz  2015.00       6.750000       8.120000  18796.000000
# 7         s cross  2015.00       6.500000       8.610000  33429.000000
# 8            ciaz  2016.00       8.750000       8.890000  20273.000000
# 9             NaN  2015.00       7.450000       7.269231  42367.000000
# 10       alto 800  2017.00       2.850000       3.600000   2135.000000
# 11           ciaz  2014.28       6.850000      10.380000  51000.000000
# ...

# %%
# Filter data based on a condition (e.g., Selling_Price greater than 5)
filtered_data = df[df['Selling_Price'] > 5]
print(df)
# Out:
#          Car_Name     Year  Selling_Price  Present_Price    Kms_Driven  \
# 0            ritz  2014.00       3.350000       7.269231  27000.000000
# 1             sx4  2013.00       4.750000       9.540000  43000.000000
# 2            ciaz  2017.00       7.250000       9.850000   6900.000000
# 3         wagon r  2014.28       2.850000       4.150000   5200.000000
# 4           swift  2014.00       4.600000       6.870000  42450.000000
# 5   vitara brezza  2018.00       4.967857       9.830000   2071.000000
# 6            ciaz  2015.00       6.750000       8.120000  18796.000000
# 7         s cross  2015.00       6.500000       8.610000  33429.000000
# 8            ciaz  2016.00       8.750000       8.890000  20273.000000
# 9             NaN  2015.00       7.450000       7.269231  42367.000000
# 10       alto 800  2017.00       2.850000       3.600000   2135.000000
# 11           ciaz  2014.28       6.850000      10.380000  51000.000000
# ...

# %%
# Create a dictionary of lists
data_dict = {
    'Car_Name': ['ritz', 'sx4', 'ciaz'],
    'Year': [2014, 2013, 2017],
    'Selling_Price': [3.35, 4.75, 7.25],
    # Add other columns as needed
}
print(data_dict)
# Out:
# {'Car_Name': ['ritz', 'sx4', 'ciaz'], 'Year': [2014, 2013, 2017], 'Selling_Price': [3.35, 4.75, 7.25]}

# %%
new_df = pd.DataFrame(data_dict)
non_null_check = df.notnull()
print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 new_df = pd.DataFrame(data_dict)
#       2 non_null_check = df.notnull()
#       3 print(df)
#
# NameError: name 'pd' is not defined

# %%
df_filled = df.fillna(0)
df_filled
# Out:
#          Car_Name     Year  Selling_Price  Present_Price    Kms_Driven  \
# 0            ritz  2014.00       3.350000       7.269231  27000.000000
# 1             sx4  2013.00       4.750000       9.540000  43000.000000
# 2            ciaz  2017.00       7.250000       9.850000   6900.000000
# 3         wagon r  2014.28       2.850000       4.150000   5200.000000
# 4           swift  2014.00       4.600000       6.870000  42450.000000
# 5   vitara brezza  2018.00       4.967857       9.830000   2071.000000
# 6            ciaz  2015.00       6.750000       8.120000  18796.000000
# 7         s cross  2015.00       6.500000       8.610000  33429.000000
# 8            ciaz  2016.00       8.750000       8.890000  20273.000000
# 9               0  2015.00       7.450000       7.269231  42367.000000
# 10       alto 800  2017.00       2.850000       3.600000   2135.000000
# 11           ciaz  2014.28       6.850000      10.380000  51000.000000
# ...
